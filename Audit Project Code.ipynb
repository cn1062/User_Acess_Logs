# %% [markdown]
# # Audit Project Code

# %%
import pandas as pd 
employees_df = pd.read_csv('data/employees.csv')
employees_df.head()
# Out:
#   employee_number first_name last_name                             email  \
# 0       EMP003037    Juliana  Burbudge  juliana.burbudge@consultants.com
# 1       EMP003045     Lizzie      Blue       lizzie.blue@consultants.com
# 2       EMP003051    Marjory  Selcraig  marjory.selcraig@consultants.com
# 3       EMP003068     Aguste  O'Connor   aguste.o'connor@consultants.com
# 4       EMP003097    Clemens    Kopman    clemens.kopman@consultants.com
#
#                title
# 0  Director of Sales
# 1    Sales Assistant
# 2    Sales Assistant
# 3    Sales Assistant
# 4    Account Manager

# %%
system_access_df = pd.read_csv('data/system_access.csv')
system_access_df.head()
# Out:
#      id    access_level
# 0  3045  Contract Entry
# 1  3051  Contract Entry
# 2  3068  Contract Entry
# 3  3097   Account Admin
# 4  3133  Contract Entry

# %%
system_access_df['id'] = 'EMP' + system_access_df['id'].astype(str).str.zfill(6)
system_access_df
# Out:
#             id    access_level
# 0    EMP003045  Contract Entry
# 1    EMP003051  Contract Entry
# 2    EMP003068  Contract Entry
# 3    EMP003097   Account Admin
# 4    EMP003133  Contract Entry
# ..         ...             ...
# 833  EMP024862  Contract Entry
# 834  EMP024864  Contract Entry
# 835  EMP024885   Account Admin
# 836  EMP024890  Contract Entry
# 837  EMP024896   Account Admin
#
# [838 rows x 2 columns]

# %%
system_access_df.rename(columns={'id':'employee_number'}, inplace=True)

employees_df.set_index('employee_number', inplace=True)

system_access_df.set_index('employee_number', inplace=True)
df = employees_df.join(system_access_df , how = 'left')
df.head()
# Out:
#                 first_name last_name                             email  \
# employee_number
# EMP003037          Juliana  Burbudge  juliana.burbudge@consultants.com
# EMP003045           Lizzie      Blue       lizzie.blue@consultants.com
# EMP003051          Marjory  Selcraig  marjory.selcraig@consultants.com
# EMP003068           Aguste  O'Connor   aguste.o'connor@consultants.com
# EMP003097          Clemens    Kopman    clemens.kopman@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin

# %%
subset_df=df.loc[df['access_level'].isnull()]
subset_df
# Out:
#                  first_name last_name                             email  \
# employee_number
# EMP003037           Juliana  Burbudge  juliana.burbudge@consultants.com
# EMP003265            Natala      Judd       natala.judd@consultants.com
# EMP003291           Gweneth    Abbate    gweneth.abbate@consultants.com
# EMP003684          Annmarie   Scrange  annmarie.scrange@consultants.com
# EMP003713          Marybeth   Driussi  marybeth.driussi@consultants.com
# ...                     ...       ...                               ...
# EMP024068           Celinka   Vasilic   celinka.vasilic@consultants.com
# EMP024191             Danny    Vinten      danny.vinten@consultants.com
# EMP024501            Fedora     Belle      fedora.belle@consultants.com
# EMP024551              Ravi   Dighton      ravi.dighton@consultants.com
# EMP024931        Frederique      Fant   frederique.fant@consultants.com
#
#                              title access_level
# employee_number
# ...

# %%
df.loc[df['title']=='Director of Sales']
# Out:
#                   first_name   last_name  \
# employee_number
# EMP003037            Juliana    Burbudge
# EMP003265             Natala        Judd
# EMP003684           Annmarie     Scrange
# EMP003921           Sigfried      McTear
# EMP003952            Shandee      Apfler
# ...                      ...         ...
# EMP023935        Ulrikaumeko  Plumridege
# EMP024068            Celinka     Vasilic
# EMP024191              Danny      Vinten
# EMP024596             Munroe      Shovel
# EMP024740           Ebenezer     Worsnap
#
#                                                   email              title  \
# employee_number
# EMP003037              juliana.burbudge@consultants.com  Director of Sales
# EMP003265                   natala.judd@consultants.com  Director of Sales
# EMP003684              annmarie.scrange@consultants.com  Director of Sales
# EMP003921               sigfried.mctear@consultants.com  Director of Sales
# ...

# %%
subset_df.loc[subset_df['title'] == 'Account Manager', 'access_level'] = 'Account Admin'
subset_df.tail()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-7-671a4977fc33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.loc[subset_df['title'] == 'Account Manager', 'access_level'] = 'Account Admin'
#                  first_name last_name                            email  \
# employee_number
# EMP024068           Celinka   Vasilic  celinka.vasilic@consultants.com
# EMP024191             Danny    Vinten     danny.vinten@consultants.com
# ...

# %%
subset_df.loc[subset_df['title'] == 'Sales Assistant', 'access_level'] = 'Contract Entry'
subset_df.tail()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-8-7554ec839825>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.loc[subset_df['title'] == 'Sales Assistant', 'access_level'] = 'Contract Entry'
#                  first_name last_name                            email  \
# employee_number
# EMP024068           Celinka   Vasilic  celinka.vasilic@consultants.com
# EMP024191             Danny    Vinten     danny.vinten@consultants.com
# ...

# %%
subset_df.loc[subset_df['title'] == 'Director of Sales', 'access_level'] = 'Approval - Manager'
subset_df.tail()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-9-80a98a275d41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_df.loc[subset_df['title'] == 'Director of Sales', 'access_level'] = 'Approval - Manager'
#                  first_name last_name                            email  \
# employee_number
# EMP024068           Celinka   Vasilic  celinka.vasilic@consultants.com
# EMP024191             Danny    Vinten     danny.vinten@consultants.com
# ...

# %%
subset_df.to_csv('results.csv')
